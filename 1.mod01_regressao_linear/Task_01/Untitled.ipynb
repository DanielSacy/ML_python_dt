# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
pd.set_option('display.max_columns', None)

data = pd.read_csv('./kc_house_data.csv')

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
clean1 = data[['price', 'bedrooms', 'bathrooms','sqft_living', 'sqft_lot', 'yr_built', 'yr_renovated', 'sqft_living15', 'sqft_lot15', 'floors', 'waterfront', 'view', 'grade', 'sqft_above', 'sqft_basement']]

# %%
clean1.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  yr_built  \
# 0  221900.0         3       1.00         1180      5650      1955
# 1  538000.0         3       2.25         2570      7242      1951
# 2  180000.0         2       1.00          770     10000      1933
# 3  604000.0         4       3.00         1960      5000      1965
# 4  510000.0         3       2.00         1680      8080      1987
#
#    yr_renovated  sqft_living15  sqft_lot15  floors  waterfront  view  grade  \
# 0             0           1340        5650     1.0           0     0      7
# 1          1991           1690        7639     2.0           0     0      7
# 2             0           2720        8062     1.0           0     0      6
# 3             0           1360        5000     1.0           0     0      7
# 4             0           1800        7503     1.0           0     0      8
#
#    sqft_above  sqft_basement
# 0        1180              0
# 1        2170            400
# ...

# %%
label = clean1['price']
features = clean1[clean1.columns[1:]]

# %%
label.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %%
features.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  yr_built  yr_renovated  \
# 0         3       1.00         1180      5650      1955             0
# 1         3       2.25         2570      7242      1951          1991
# 2         2       1.00          770     10000      1933             0
# 3         4       3.00         1960      5000      1965             0
# 4         3       2.00         1680      8080      1987             0
#
#    sqft_living15  sqft_lot15  floors  waterfront  view  grade  sqft_above  \
# 0           1340        5650     1.0           0     0      7        1180
# 1           1690        7639     2.0           0     0      7        2170
# 2           2720        8062     1.0           0     0      6         770
# 3           1360        5000     1.0           0     0      7        1050
# 4           1800        7503     1.0           0     0      8        1680
#
#    sqft_basement
# 0              0
# 1            400
# 2              0
# 3            910
# ...

# %%
label.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 21613 entries, 0 to 21612
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 21613 non-null  float64
# dtypes: float64(1)
# memory usage: 169.0 KB

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bedrooms       21613 non-null  int64
#  1   bathrooms      21613 non-null  float64
#  2   sqft_living    21613 non-null  int64
#  3   sqft_lot       21613 non-null  int64
#  4   yr_built       21613 non-null  int64
#  5   yr_renovated   21613 non-null  int64
#  6   sqft_living15  21613 non-null  int64
#  7   sqft_lot15     21613 non-null  int64
#  8   floors         21613 non-null  float64
#  9   waterfront     21613 non-null  int64
#  10  view           21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
# dtypes: float64(2), int64(12)
# memory usage: 2.3 MB

# %%
model = LinearRegression()

# %%
features_train, features_test, label_train, label_test = train_test_split(features, label, test_size=.3, shuffle=True)

# %%
features_train.shape
# Out:
# (15129, 14)

# %%
label_train.shape
# Out:
# (15129,)

# %%
model.fit(features_train, label_train)
# Out:
# LinearRegression()

# %%
plt.scatter(features_train, label_train)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 plt.scatter(features_train, label_train)
#       2 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2862, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2857 @_copy_docstring_and_deprecators(Axes.scatter)
#    2858 def scatter(
#    2859         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2864         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
# ...
