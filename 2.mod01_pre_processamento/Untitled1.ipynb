# %%
import pandas as pd
pd.set_option("display.max_columns", None)
data = pd.read_csv("E:/DAY2DAY/Python_MachineLearning_DidaticaTech/ML_python_dt/2.mod01_pre_processamento/dataset/2015-building-energy-benchmarking.csv")

# %%
data.dtypes
# Out:
# OSEBuildingID                                                      int64
# DataYear                                                           int64
# BuildingType                                                      object
# PrimaryPropertyType                                               object
# PropertyName                                                      object
# TaxParcelIdentificationNumber                                     object
# Location                                                          object
# CouncilDistrictCode                                                int64
# Neighborhood                                                      object
# YearBuilt                                                          int64
# NumberofBuildings                                                  int64
# NumberofFloors                                                   float64
# PropertyGFATotal                                                   int64
# ...

# %%
data_int = data.select_dtypes(include=['int64', 'float64'])

# %%
data_int.dtypes
# Out:
# OSEBuildingID                                                      int64
# DataYear                                                           int64
# CouncilDistrictCode                                                int64
# YearBuilt                                                          int64
# NumberofBuildings                                                  int64
# NumberofFloors                                                   float64
# PropertyGFATotal                                                   int64
# PropertyGFAParking                                                 int64
# PropertyGFABuilding(s)                                             int64
# LargestPropertyUseTypeGFA                                        float64
# SecondLargestPropertyUseTypeGFA                                  float64
# ThirdLargestPropertyUseTypeGFA                                   float64
# ENERGYSTARScore                                                  float64
# ...

# %%
pd.set_option('display.width', 200)
pd.set_option('display.width', 200)
correlations = data_int.corr(method='pearson')
print(correlations)
# Out:
#                                                     OSEBuildingID  DataYear  CouncilDistrictCode  YearBuilt  NumberofBuildings  NumberofFloors  PropertyGFATotal  PropertyGFAParking  \
# OSEBuildingID                                            1.000000       NaN            -0.092519   0.134578          -0.000676       -0.113519         -0.268611           -0.179414
# DataYear                                                      NaN       NaN                  NaN        NaN                NaN             NaN               NaN                 NaN
# CouncilDistrictCode                                     -0.092519       NaN             1.000000  -0.023185          -0.025065        0.243339          0.143526            0.152531
# YearBuilt                                                0.134578       NaN            -0.023185   1.000000          -0.004222        0.142683          0.181080            0.248852
# ...
